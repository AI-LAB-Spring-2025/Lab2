# %%
import numpy as np
import matplotlib.pyplot as plt

arr1 =np.array( [12, 15, 14, 13, 16, 18, 19, 15, 14, 20, 17, 14, 15,40,45,50,62])
arr2 = np.array([12, 17, 15, 13, 19, 20, 21, 18, 17, 16, 15, 14, 16, 15])

#print

fig = plt.figure(figsize =(10, 7))

# Creating plot

plt.boxplot(arr1)
plt.boxplot(arr2)
# show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

file=open("genome.txt","r")

content=file.read().strip()

List1=list(content)
genome_length=len(List1)
t = np.linspace(0, 4 * np.pi, genome_length) # 4*pi gives about

x = np.cos(t)
y = np.sin(t)
z = np.linspace(0, 5, genome_length)
# Generate random genome sequence
nucleotides = ["A", "T", "C", "G"]

genome = ""

# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
# Generate random coordinates for each nucleotide
coordinates = np.column_stack((x, y, z))

# Color mapping
colors = {'A': 'red', 'T': 'blue', 'C': 'green', 'G': 'orange'}
# Plot each nucleotide with its corresponding color and coordinates
for i, nucleotide in enumerate(List1):
 ax.scatter(coordinates[i, 0], coordinates[i, 1], coordinates[i, 2],
 color=colors[nucleotide], marker='o')
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_title("Genome Visualization")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open('download.jpg')

# asarray() class is used to convert
# PIL images into NumPy arrays
numpydata = np.asarray(img)
plt.imshow(numpydata)
plt.show()

#rotate image
rotate_image=np.rot90(numpydata)
plt.imshow(rotate_image)
plt.show()

flip_image= np.fliplr(numpydata)
plt.imshow(flip_image)
plt.show()

gray_img = np.dot (numpydata[..., :3], [0.299, 0.587, 0.114])
plt.imshow(gray_img)
plt.show()

# %%
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt


iris = load_iris()


X = np.array(iris.data)
Y = np.array(iris.target)




num_features = X.shape[1]
feature_names = iris['feature_names']

print("NumPy Calculations:\n")

for i in range(num_features):
    feature_data = X[:, i]
    mean_val = np.mean(feature_data)
    median_val = np.median(feature_data)
    std_dev_val = np.std(feature_data)
    min_val = np.min(feature_data)
    max_val = np.max(feature_data)

    print(f"Feature: {feature_names[i]}")
    print(f"  Mean: {mean_val:.2f}")
    print(f"  Median: {median_val:.2f}")
    print(f"  Standard Deviation: {std_dev_val:.2f}")
    print(f"  Minimum: {min_val:.2f}")
    print(f"  Maximum: {max_val:.2f}\n")


sepal_data = X[:, :2]
print("Sepal Length and Width Data:\n", sepal_data[:5])




print("\nMatplotlib Visualizations:")


plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title('Sepal Length vs Sepal Width')
plt.colorbar(label='Species', ticks=[0, 1, 2])
plt.show()


plt.figure(figsize=(8, 6))
plt.hist(X[:, 0], bins=20, color='skyblue', edgecolor='black')
plt.xlabel(iris.feature_names[0])
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Length')
plt.show()


plt.figure(figsize=(8, 6))
plt.plot(X[:, 2], X[:, 3], marker='o', linestyle='-', color='purple')
plt.xlabel(iris.feature_names[2])
plt.ylabel(iris.feature_names[3])
plt.title('Petal Length vs Petal Width')
plt.grid(True)
plt.show()
# Out:
# NumPy Calculations:
#
# Feature: sepal length (cm)
#   Mean: 5.84
#   Median: 5.80
#   Standard Deviation: 0.83
#   Minimum: 4.30
#   Maximum: 7.90
#
# Feature: sepal width (cm)
#   Mean: 3.06
#   Median: 3.00
#   Standard Deviation: 0.43
#   Minimum: 2.00
#   Maximum: 4.40
#
# Feature: petal length (cm)
#   Mean: 3.76
#   Median: 4.35
#   Standard Deviation: 1.76
#   Minimum: 1.00
#   Maximum: 6.90
#
# Feature: petal width (cm)
#   Mean: 1.20
#   Median: 1.30
#   Standard Deviation: 0.76
#   Minimum: 0.10
#   Maximum: 2.50
#
# Sepal Length and Width Data:
#  [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]]
#
# Matplotlib Visualizations:
