# %%
import numpy as np
import matplotlib.pyplot as plt
group_A = [12, 15, 14, 13, 16, 18, 19, 15, 14, 20, 17, 14, 15,40,45,50,62]
group_B = [12, 17, 15, 13, 19, 20, 21, 18, 17, 16, 15, 14, 16, 15]

fig = plt.figure(figsize =(10, 7))

plt.boxplot(group_A)

plt.show()
plt.boxplot(group_B)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
file = open("genome.txt", "r")
content = file.read().strip()
list1=list(content)
length=len(list1)
t = np.linspace(0, 4 * np.pi, length)
x = np.cos(t)
y = np.sin(t)
z = np.linspace(0, 5, length)
nucleotides = ["A", "T", "C", "G"]
colors = {'A': 'red', 'T': 'blue', 'C': 'green', 'G': 'orange'}
coordinates = np.column_stack((x, y, z))
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")

for i, nucleotide in enumerate(list1):
 ax.scatter(coordinates[i, 0], coordinates[i, 1], coordinates[i, 2],
 color=colors[nucleotide], marker='o')

plt.title("simple 3D scatter plot")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import asarray
from PIL import Image
image = Image.open('random.jfif')
numpydata = np.asarray(image)
plt.imshow(numpydata)
plt.show()
rotated_img=np.rot90(numpydata)
plt.imshow(rotated_img)
plt.show()
flipedd_img=np.fliplr(numpydata)
plt.imshow(flipedd_img)
plt.show()
gray_img = np.dot (numpydata[..., :3], [0.299, 0.587, 0.114])
plt.imshow(gray_img, cmap='gray')
plt.show()

# %%
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt

iris = load_iris()

X = np.array(iris.data)
Y = np.array(iris.target)

mean_values = np.mean(X, axis=0)
median_values = np.median(X, axis=0)
std_values = np.std(X, axis=0)

print("Mean of each feature:", mean_values)
print("Median of each feature:", median_values)
print("Standard deviation of each feature:", std_values)


min_values = np.min(X, axis=0)
max_values = np.max(X, axis=0)

print("Minimum values of each feature:", min_values)
print("Maximum values of each feature:", max_values)


sepal_features = X[:, :2]
print("Sepal length and sepal width:\n", sepal_features)

plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap='viridis')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Scatter Plot: Sepal Length vs Sepal Width')
plt.colorbar(label='Species')
plt.show()

plt.figure(figsize=(8, 6))
plt.hist(X[:, 0], bins=20, color='blue', edgecolor='black')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Histogram: Distribution of Sepal Length')
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(X[:, 2], X[:, 3], color='red', marker='o', linestyle='-')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Line Plot: Petal Length vs Petal Width')
plt.show()
# Out:
# Mean of each feature: [5.84333333 3.05733333 3.758      1.19933333]
# Median of each feature: [5.8  3.   4.35 1.3 ]
# Standard deviation of each feature: [0.82530129 0.43441097 1.75940407 0.75969263]
# Minimum values of each feature: [4.3 2.  1.  0.1]
# Maximum values of each feature: [7.9 4.4 6.9 2.5]
# Sepal length and sepal width:
#  [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]
#  [5.4 3.9]
#  [4.6 3.4]
#  [5.  3.4]
#  [4.4 2.9]
#  [4.9 3.1]
#  [5.4 3.7]
#  [4.8 3.4]
#  [4.8 3. ]
#  [4.3 3. ]
#  [5.8 4. ]
#  [5.7 4.4]
#  [5.4 3.9]
#  [5.1 3.5]
#  [5.7 3.8]
#  [5.1 3.8]
#  [5.4 3.4]
#  [5.1 3.7]
#  [4.6 3.6]
#  [5.1 3.3]
#  [4.8 3.4]
#  [5.  3. ]
#  [5.  3.4]
#  [5.2 3.5]
#  [5.2 3.4]
#  [4.7 3.2]
#  [4.8 3.1]
#  [5.4 3.4]
#  [5.2 4.1]
#  [5.5 4.2]
#  [4.9 3.1]
#  [5.  3.2]
#  [5.5 3.5]
#  [4.9 3.6]
#  [4.4 3. ]
#  [5.1 3.4]
#  [5.  3.5]
#  [4.5 2.3]
#  [4.4 3.2]
#  [5.  3.5]
#  [5.1 3.8]
#  [4.8 3. ]
#  [5.1 3.8]
#  [4.6 3.2]
#  [5.3 3.7]
#  [5.  3.3]
# ...
